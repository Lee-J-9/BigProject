# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
pop = pd.read_csv('등록인구_20250106104440.csv')
size = pd.read_csv('행정구역(구별)_20250106104639.csv')
t_can = pd.read_csv('____________.csv')

# %%
# 구 별 인원 뽑아내기
pop1 = pop[['동별(2)','2024 3/4.1']].copy()
pop1 = pop1.drop(index = [0,1,2]).reset_index(drop=True)
pop1.columns = ['구','인구 수']
pop1.head()
# Out:
#      구    인구 수
# 0  종로구  150011
# 1   중구  131589
# 2  용산구  218370
# 3  성동구  282385
# 4  광진구  349307

# %%
# 구 별 면적 뽑아내기
size1 = size.iloc[:,[1,2]].copy()
size1 = size1.drop(index = [0,1,2]).reset_index(drop=True)
size1.columns=['구','면적']
size1.head()
# Out:
#      구     면적
# 0  종로구  23.91
# 1   중구   9.96
# 2  용산구  21.87
# 3  성동구  16.82
# 4  광진구  17.06

# %%
# 병합
seoul_stats = pd.merge(pop1,size1, on = '구').reset_index(drop = True)
seoul_stats.rename(columns={'인구 수':'인구'}, inplace = True)

# %%
seoul_stats.info
seoul_stats['인구'] = seoul_stats['인구'].astype(int)
seoul_stats['면적'] = seoul_stats['면적'].astype(float)
seoul_stats['인구밀도'] = (seoul_stats['인구'] / seoul_stats['면적']).round(1)
seoul_stats.head()
# Out:
#      구      인구     면적     인구밀도
# 0  종로구  150011  23.91   6274.0
# 1   중구  131589   9.96  13211.7
# 2  용산구  218370  21.87   9984.9
# 3  성동구  282385  16.82  16788.6
# 4  광진구  349307  17.06  20475.2

# %%
t_can.head()
seoul_stats = pd.merge(seoul_stats, t_can, left_on = '구',right_on = '자치구명')
seoul_stats = seoul_stats.drop(columns=['자치구명'])
# Out:
#      구      인구     면적     인구밀도  쓰레기통 대수
# 0  종로구  150011  23.91   6274.0      272
# 1   중구  131589   9.96  13211.7      146
# 2  용산구  218370  21.87   9984.9      278
# 3  성동구  282385  16.82  16788.6      102
# 4  광진구  349307  17.06  20475.2      104

# %%
seoul_stats = seoul_stats.sort_values(by='구').reset_index(drop=True)
# Out:
#      구      인구     면적     인구밀도  쓰레기통 대수
# 0  강남구  564280  39.50  14285.6      974
# 1  강동구  469464  24.59  19091.7       52
# 2  강북구  289678  23.60  12274.5      217
# 3  강서구  563515  41.45  13595.1      315
# 4  관악구  496469  29.57  16789.6      108

# %%
seoul_stats['인구/쓰레기통'] = seoul_stats['인구'] / seoul_stats['쓰레기통 대수']
seoul_stats['면적/쓰레기통'] = seoul_stats['면적'] / seoul_stats['쓰레기통 대수']
seoul_stats['밀도당 쓰레기통'] = seoul_stats['인구밀도'] / seoul_stats['쓰레기통 대수']
seoul_stats.head()
# Out:
#      구      인구     면적     인구밀도  쓰레기통 대수  인구당 쓰레기통   면적당 쓰레기통    밀도당 쓰레기통  \
# 0  강남구  564280  39.50  14285.6      974  0.001726  24.658228   14.666940
# 1  강동구  469464  24.59  19091.7       52  0.000111   2.114681  367.148077
# 2  강북구  289678  23.60  12274.5      217  0.000749   9.194915   56.564516
# 3  강서구  563515  41.45  13595.1      315  0.000559   7.599517   43.159048
# 4  관악구  496469  29.57  16789.6      108  0.000218   3.652350  155.459259
#
#    10000명당 쓰레기통      인구/쓰레기통   면적/쓰레기통
# 0     17.260934   579.342916  0.040554
# 1      1.107646  9028.153846  0.472885
# 2      7.491076  1334.921659  0.108756
# 3      5.589913  1788.936508  0.131587
# 4      2.175362  4596.935185  0.273796

# %%
seoul_stats.drop(columns = '1000명당 쓰레기통',inplace = True)
seoul_stats.head(3)
# Out:
#      구      인구     면적     인구밀도  쓰레기통 대수  인구당 쓰레기통   면적당 쓰레기통   밀도당 쓰레기통  \
# 0  강남구  564280  39.50  14285.6      974  0.001726  24.658228  68.180545
# 1  강동구  469464  24.59  19091.7       52  0.000111   2.114681   2.723697
# 2  강북구  289678  23.60  12274.5      217  0.000749   9.194915  17.678928
#
#    10000명당 쓰레기통
# 0     17.260934
# 1      1.107646
# 2      7.491076

# %%
seoul_stats.to_csv('서울기초통계.csv', index=False, encoding='utf-8-sig')

# %%
import matplotlib.font_manager as fm

# 나눔글꼴 경로 설정
font_path = 'C:\Windows\Fonts\malgun.ttf'

# 폰트 이름 가져오기
font_name = fm.FontProperties(fname=font_path).get_name()

# 폰트 설정
plt.rc('font', family=font_name)
# 출처: https://giveme-happyending.tistory.com/168 [소연의_개발일지:티스토리]

plt.figure(figsize=(20, 6))
plt.bar(seoul_stats['구'], seoul_stats['인구/쓰레기통'], color='blue', alpha=0.7)
plt.title('Trash Cans per Person')
plt.xlabel('District')
plt.ylabel('Trash Cans per Person')
plt.show()
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\W'
# <>:4: SyntaxWarning: invalid escape sequence '\W'
# C:\Users\User\AppData\Local\Temp\ipykernel_23580\2425676863.py:4: SyntaxWarning: invalid escape sequence '\W'
#   font_path = 'C:\Windows\Fonts\malgun.ttf'

# %%
plt.figure(figsize=(20, 6))
plt.bar(seoul_stats['구'], seoul_stats['인구당 쓰레기통'], color='blue', alpha=0.7)
plt.title('Trash Cans per Person')
plt.xlabel('District')
plt.ylabel('Trash Cans per Person')
plt.show()

# %%
trash = pd.read_excel('TrashCans.xlsx')
trash.head()
# Out:
#      구   쓰레기통
# 0  종로구  308.0
# 1   중구  196.0
# 2  용산구  284.0
# 3  성동구  102.0
# 4  광진구  118.0

# %%
trash23 = pd.read_csv('Trashcans2023.csv')
trash23.head()
# Out:
#   자치구명  쓰레기통 대수
# 0  강남구      974
# 1  강동구       52
# 2  강북구      217
# 3  강서구      315
# 4  관악구      108

# %%
trash23.rename(columns = {'자치구명':'구','쓰레기통 대수':'쓰레기통2023'},inplace = True)
trash23.head()
# Out:
#      구  쓰레기통2023
# 0  강남구       974
# 1  강동구        52
# 2  강북구       217
# 3  강서구       315
# 4  관악구       108

# %%
t_data = pd.merge(trash23,trash,on = '구')
t_data
# Out:
#        구  쓰레기통2023   쓰레기통
# 0    강남구       974  976.0
# 1    강동구        52   52.0
# 2    강북구       217  229.0
# 3    강서구       315  315.0
# 4    관악구       108  212.0
# 5    광진구       104  118.0
# 6    구로구       221  230.0
# 7    금천구        70   70.0
# 8    노원구       156  156.0
# 9    도봉구       303  307.0
# 10  동대문구       110  114.0
# 11   동작구       230  260.0
# 12   마포구       254  259.0
# 13  서대문구       218  241.0
# 14   서초구       246  250.0
# 15   성동구       102  102.0
# 16   성북구       185  193.0
# 17   송파구       151  151.0
# 18   양천구       136  136.0
# 19  영등포구       123  191.0
# 20   용산구       278  284.0
# 21   은평구       308  342.0
# 22   종로구       272  308.0
# 23    중구       146  196.0
# 24   중랑구       101  101.0
